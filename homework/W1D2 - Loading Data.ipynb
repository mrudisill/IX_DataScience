# %% [markdown]
# # <font color='#eb3483'> Practice: Loading Data </font>
#
# In the 'data' folder are some datasets. Give yourself a head start by loading the data and getting a feel for what each dataset contains using the methods covered in class today.

# %%
# Listing the CSV files:
# !ls data/
import pandas as pd
# Out:
# CC GENERAL.csv                        census_salary.csv
# Carseats.csv                          crime_data.txt
# Emails.csv                            heart.csv
# Tractor-Sales.csv                     population_lisboa.csv
# US_Production_Q_Data_Growth_Rates.csv retail.csv
# airbnb.csv                            titanic.csv
# ames.csv
