# %% [markdown]
# # <font color='#eb3483'> Introduction to Pandas </font>

# %% [markdown]
# Pandas is Numpy's extension for Data Analysis. Among many other things, it provides a really useful data structure called a `DataFrame`. A `pandas.DataFrame` is basically a table similar to an Excel spreadsheet with rows and columns. If you have experience with the R programming language, the `pandas.DataFrame` is very similar to an R `data.frame`.
#
# http://pandas.pydata.org/
#
# The standard way of importing pandas is:

# %%
import pandas as pd

# %% [markdown]
# In this notebook we will cover:
# <font color='#eb3483'>
# 1. Dataframes
# 1. Reading and writing a data frame
# 1. Inspecting a data frame
# 1. Indexing
#
#     </font>

# %% [markdown]
# ##  <font color='#eb3483'> 1. Building DataFrames </font>

# %% [markdown]
# There are many ways to create a dataframe

# %%
#We can feed in a 2D list and specify column names - and make the data frame with the function DataFrame()
rick_morty = pd.DataFrame(
    [
        ["Rick", "Sanchez", 60],
        ["Morty", "Smith", 14]
    ], columns = ["first_name", "last_name", "age"]
)
rick_morty
# Out:
#   first_name last_name  age
# 0       Rick   Sanchez   60
# 1      Morty     Smith   14

# %%
type(rick_morty)
# Out:
# pandas.core.frame.DataFrame

# %%
#We can take a peak of our dataframe using the built-in head method .head() and also .(tail)

a = rick_morty.head()
b = rick_morty.tail(1)

print(a)
print(b)
# Out:
#   first_name last_name  age
# 0       Rick   Sanchez   60
# 1      Morty     Smith   14
#   first_name last_name  age
# 1      Morty     Smith   14

# %%
#we can also ask to return a specific row by refering to the row index:
print(rick_morty.loc[0])
print(rick_morty.loc[1])
# Out:
# first_name       Rick
# last_name     Sanchez
# age                60
# Name: 0, dtype: object
# first_name    Morty
# last_name     Smith
# age              14
# Name: 1, dtype: object

# %% [markdown]
# We can create an empty dataframe

# %%
df3 = pd.DataFrame()

# %%
#It's as you would expect ... empty
print(df3)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Now lets add columns to the empty dataframe

# %%
df3['Colours'] = ["Red", "Yellow", "Blue"]
print(df3)
# Out:
#   Colours
# 0     Red
# 1  Yellow
# 2    Blue

# %%
#assign it to column 'number' in df3

df3['Number']= [28,29, 30]
print(df3)
# Out:
#   Colours  Number
# 0     Red      28
# 1  Yellow      29
# 2    Blue      30

# %% [markdown]
# We can see the column names with `.columns`

# %%
#Let's sort by name
df3.columns
# Out:
# Index(['Colours', 'Number'], dtype='object')

# %% [markdown]
# We can see the values of a column

# %%
df3["Colours"]
# Out:
# 0       Red
# 1    Yellow
# 2      Blue
# Name: Colours, dtype: object

# %% [markdown]
# We can also sort our dataframe by our columns

# %%
df3.sort_values(by="Number", ascending=True)
# Out:
#   Colours  Number
# 0     Red      28
# 1  Yellow      29
# 2    Blue      30

# %%
#Try and sort by number value

#How can we change this to descending?
#descending -- False
df3.sort_values(by="Number", ascending=False)
# Out:
#   Colours  Number
# 2    Blue      30
# 1  Yellow      29
# 0     Red      28

# %% [markdown]
# How do we get help ... lets try a few things

# %% [markdown]
# Selecting a column that does not exists will raise a `KeyError` (same error as when selecting a missing key in a dictionary)

# %%
df3["Black"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Black'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df3["Black"]
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Black'

# %% [markdown]
# ## <font color='#eb3483'> 2. Reading/Writing data with dataframes </font>

# %% [markdown]
# It's not very often we have to create our own data frame but now we know just incase.
# Pandas can import from and export to many types of files, csv, json, excel among others.
#
# For example, we can read a csv including information about the Avengers (taken from [here](https://github.com/fivethirtyeight/data/tree/master/avengers))

# %%
# read in data
avengers = pd.read_csv("data/avengers.csv")
print(avengers)
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                             name  appearances current  gender  starting_date  \
# 0      Henry Jonathan "Hank" Pym         1269     YES    MALE           1963
# 1                 Janet van Dyne         1165     YES  FEMALE           1963
# 2    Anthony Edward "Tony" Stark         3068     YES    MALE           1963
# 3            Robert Bruce Banner         2089     YES    MALE           1963
# 4                   Thor Odinson         2402     YES    MALE           1963
# ..                           ...          ...     ...     ...            ...
# 168                  Eric Brooks          198     YES    MALE           2013
# 169                Adam Brashear           29     YES    MALE           2014
# 170               Victor Alvarez           45     YES    MALE           2014
# 171                    Ava Ayala           49     YES  FEMALE           2014
# 172                        Kaluu           35     YES    MALE           2015
#
#                                                  notes
# 0    Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1    Dies in Secret Invasion V1:I8. Actually was se...
# 2    Death: "Later while under the influence of Imm...
# 3    Dies in Ghosts of the Future arc. However "he ...
# 4    Dies in Fear Itself brought back because that'...
# ..                                                 ...
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
#
# [173 rows x 7 columns]

# %%
# look at the head of our data set
avengers
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                             name  appearances current  gender  starting_date  \
# 0      Henry Jonathan "Hank" Pym         1269     YES    MALE           1963
# 1                 Janet van Dyne         1165     YES  FEMALE           1963
# 2    Anthony Edward "Tony" Stark         3068     YES    MALE           1963
# 3            Robert Bruce Banner         2089     YES    MALE           1963
# 4                   Thor Odinson         2402     YES    MALE           1963
# ..                           ...          ...     ...     ...            ...
# 168                  Eric Brooks          198     YES    MALE           2013
# 169                Adam Brashear           29     YES    MALE           2014
# 170               Victor Alvarez           45     YES    MALE           2014
# 171                    Ava Ayala           49     YES  FEMALE           2014
# 172                        Kaluu           35     YES    MALE           2015
#
#                                                  notes
# 0    Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1    Dies in Secret Invasion V1:I8. Actually was se...
# 2    Death: "Later while under the influence of Imm...
# 3    Dies in Ghosts of the Future arc. However "he ...
# 4    Dies in Fear Itself brought back because that'...
# ..                                                 ...
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
#
# [173 rows x 7 columns]

# %%
avengers.shape
# Out:
# (173, 7)

# %% [markdown]
# We can save the dataframe back to a csv file with `to_csv` (this method writes the index by default as a separate column, we can avoid this by passing the argument `index=False`).

# %%
avengers.to_csv("avengers2.csv", index=False)

# %% [markdown]
# or we can export to excel using `to_excel` (it requires a separate package, `xlwt`)

# %%
avengers.to_excel("avengers.xls", index=False)
# Out:
# /var/folders/dk/95f115l12ms7fs6v815_g44c0000gn/T/ipykernel_75836/2416178272.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   avengers.to_excel("avengers.xls", index=False)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 avengers.to_excel("avengers.xls", index=False)
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/core/generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/io/formats/excel.py:918, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     914     need_save = False
#     915 else:
#     916     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     917     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 918     writer = ExcelWriter(  # type: ignore[abstract]
#     919         writer, engine=engine, storage_options=storage_options
#     920     )
#     921     need_save = True
#     923 try:
#
# File ~/Library/Python/3.11/lib/python/site-packages/pandas/io/excel/_xlwt.py:48, in XlwtWriter.__init__(self, path, engine, date_format, datetime_format, encoding, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      34 def __init__(
#      35     self,
#      36     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      46 ) -> None:
#      47     # Use the xlwt module as the Excel writer.
# ---> 48     import xlwt
#      50     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      52     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlwt'

# %% [markdown]
# Likewise we can read from a excel file easily (this requires the package `xlrd`)

# %%
advengers_relod= pd.read_excel("avengers2.xls")

# %% [markdown]
# Bothered by that extra 'Unnamed:0' column? It's the index column, which was created when you read in the data the first time. To avoid saving this column, use `index=False` when saving: `avengers.to_csv("avengers2.csv", index=False)`.

# %% [markdown]
# ## <font color='#eb3483'> 3. Inspecting a dataframe </font>

# %% [markdown]
# Once we read in a data frame - we generally have a quick look around (just as you would do in excel).
#
#
#
#
# We can see the first rows of a dataframe with `head()`

# %%
avengers.head()
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                           name  appearances current  gender  starting_date  \
# 0    Henry Jonathan "Hank" Pym         1269     YES    MALE           1963
# 1               Janet van Dyne         1165     YES  FEMALE           1963
# 2  Anthony Edward "Tony" Stark         3068     YES    MALE           1963
# 3          Robert Bruce Banner         2089     YES    MALE           1963
# 4                 Thor Odinson         2402     YES    MALE           1963
#
#                                                notes
# 0  Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1  Dies in Secret Invasion V1:I8. Actually was se...
# 2  Death: "Later while under the influence of Imm...
# 3  Dies in Ghosts of the Future arc. However "he ...
# 4  Dies in Fear Itself brought back because that'...

# %% [markdown]
# and the last ones with tail()

# %%
avengers.tail(10)
# Out:
#                                                    URL            name  \
# 163  http://marvel.wikia.com/Tony_Masters_(Earth-616)#    Tony Masters
# 164  http://marvel.wikia.com/Victor_Mancha_(Earth-6...   Victor Mancha
# 165  http://marvel.wikia.com/Monica_Chang_(Earth-616)#    Monica Chang
# 166  http://marvel.wikia.com/Doombot_(Avenger)_(Ear...             NaN
# 167        http://marvel.wikia.com/Alexis_(Earth-616)#          Alexis
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#     Eric Brooks
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...   Adam Brashear
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...  Victor Alvarez
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#       Ava Ayala
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#           Kaluu
#
#      appearances current  gender  starting_date  \
# 163          173      NO    MALE           2013
# 164           75     YES    MALE           2013
# 165           12     YES  FEMALE           2013
# 166           14     YES    MALE           2013
# 167           13     YES  FEMALE           2013
# 168          198     YES    MALE           2013
# 169           29     YES    MALE           2014
# 170           45     YES    MALE           2014
# 171           49     YES  FEMALE           2014
# 172           35     YES    MALE           2015
#
#                                                  notes
# 163                                                NaN
# 164  Died in Avengers_A.I._Vol_1_4. Returned in Ave...
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN

# %% [markdown]
# We can see the size of a dataframe (n_rows, n_columns) with `shape`

# %%
avengers.shape
# Out:
# (173, 7)

# %% [markdown]
# We can see the data type of each column with `dtypes`

# %%
avengers.dtypes
# Out:
# URL              object
# name             object
# appearances       int64
# current          object
# gender           object
# starting_date     int64
# notes            object
# dtype: object

# %%
print(avengers.loc[110:115])
# Out:
#                                                    URL            name  \
# 110    http://marvel.wikia.com/Maria_Hill_(Earth-616)#      Maria Hill
# 111  http://marvel.wikia.com/Robert_Baldwin_(Earth-...  Robbie Baldwin
# 112  http://marvel.wikia.com/Sharon_Carter_(Earth-6...   Sharon Carter
# 113  http://marvel.wikia.com/Eric_O%27Grady_(Earth-...    Eric O'Grady
# 114    http://marvel.wikia.com/Brunnhilde_(Earth-616)#      Brunnhilde
# 115  http://marvel.wikia.com/Richard_Rider_(Earth-6...   Richard Rider
#
#      appearances current  gender  starting_date  \
# 110          359     YES  FEMALE           2010
# 111          299      NO    MALE           2010
# 112          333      NO  FEMALE           2010
# 113           88      NO    MALE           2010
# 114          369      NO  FEMALE           2010
# 115          380      NO    MALE           2010
#
#                                                  notes
# 110                                                NaN
# 111                                                NaN
# 112  Died in Captain_America_Vol_7_10. It's not cle...
# 113                  Died in Secret_Avengers_Vol_1_22.
# 114  NA but died/came back during Ragnarok prior to...
# 115          Died in Guardians_of_the_Galaxy_Vol_3_20.

# %% [markdown]
# We can look at the column names using `.columns`

# %%
avengers.columns
# Out:
# Index(['URL', 'name', 'appearances', 'current', 'gender', 'starting_date',
#        'notes'],
#       dtype='object')

# %% [markdown]
# We can use `.describe()` to find statistical information about the dataframe's columns.

# %%
avengers.describe()
# Out:
#        appearances  starting_date
# count   173.000000     173.000000
# mean    414.052023    1988.445087
# std     677.991950      30.374669
# min       2.000000    1900.000000
# 25%      58.000000    1979.000000
# 50%     132.000000    1996.000000
# 75%     491.000000    2010.000000
# max    4333.000000    2015.000000

# %% [markdown]
# <hr>
#
# ## <font color='#eb3483'> 3. Indexes </font>

# %% [markdown]
# Dataframes have an index that allows us to perform complex data manipulations. By default, the index is the row number.

# %%
avengers.index
# Out:
# RangeIndex(start=0, stop=173, step=1)

# %% [markdown]
# We can change the index to one of the columns using `set_index()`

# %%
# lets change it the index to gender
avengers = avengers.set_index('gender')

# %%
#reset the index

# %%
# make appearances the index
avengers = avengers.set_index('appearances')

# %% [markdown]
# We can also sort our dataframe by the index using the `sort_index` command

# %%
avengers.sort_index
# Out:
# <bound method DataFrame.sort_index of                                                            URL  \
# appearances
# 1269             http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1165         http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 3068         http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 2089         http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 2402          http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ...                                                        ...
# 198           http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 29           http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 45           http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 49              http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 35                  http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                                     name current  starting_date  \
# appearances
# 1269           Henry Jonathan "Hank" Pym     YES           1963
# 1165                      Janet van Dyne     YES           1963
# 3068         Anthony Edward "Tony" Stark     YES           1963
# 2089                 Robert Bruce Banner     YES           1963
# 2402                        Thor Odinson     YES           1963
# ...                                  ...     ...            ...
# 198                          Eric Brooks     YES           2013
# 29                         Adam Brashear     YES           2014
# 45                        Victor Alvarez     YES           2014
# 49                             Ava Ayala     YES           2014
# 35                                 Kaluu     YES           2015
#
#                                                          notes
# appearances
# 1269         Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1165         Dies in Secret Invasion V1:I8. Actually was se...
# 3068         Death: "Later while under the influence of Imm...
# 2089         Dies in Ghosts of the Future arc. However "he ...
# 2402         Dies in Fear Itself brought back because that'...
# ...                                                        ...
# 198                                                        NaN
# 29                                                         NaN
# 45                                                         NaN
# 49                                                         NaN
# 35                                                         NaN
#
# [173 rows x 5 columns]>

# %%
#to make it decending we just add ascending=False argument
